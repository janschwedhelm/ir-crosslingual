# %% [markdown]
# ## Imports

# %%
import io, importlib
import datetime
import pandas as pd

import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
from ir_crosslingual.utils import paths
importlib.reload(paths)

from ir_crosslingual.features import text_based
importlib.reload(text_based)

from ir_crosslingual.embeddings import embeddings
importlib.reload(embeddings)

from ir_crosslingual.sentences import sentences
importlib.reload(sentences)
# Out:
# <module 'ir_crosslingual.sentences.sentences' from '/Users/i500969/Desktop/Admin/Uni-Mannheim/02_Courses/2020_FSS/Information-Retrieval/03_Project/03_Implementation/03_Feature-Selection/ir-crosslingual/ir_crosslingual/sentences/sentences.py'>

# %% [markdown]
# ## Load word embeddings

# %%
overall_start = datetime.datetime.now()

# %%
german = embeddings.WordEmbeddings('de')
german.load_embeddings()

english = embeddings.WordEmbeddings('en')
english.load_embeddings()

# %%
W_ende, W_deen = embeddings.WordEmbeddings.learn_projection_matrix(src_lang='en', trg_lang='de')
# Out:
# Learn projection matrix for en-de
# Found 13700 valid translation pairs in expert dictionary.
# 977 other pairs contained at least one unknown word (0 in source language, 977 in target language).
# Resulting subspace dimension: (13700, 300)
# Resulting subspace dimension: (13700, 300)
# Learn projection matrix for de-en
# Found 10604 valid translation pairs in expert dictionary.
# 262 other pairs contained at least one unknown word (0 in source language, 262 in target language).
# Resulting subspace dimension: (10604, 300)
# Resulting subspace dimension: (10604, 300)

# %% [markdown]
# ## Load sentence embeddings

# %%
start = datetime.datetime.now()
sens = sentences.Sentences(src_words=english, trg_words=german)
data = sens.load_data(single_source=False, n_max=600000, features='all', dim_red=100, agg_method='average', vectorizer=550000)
stop = datetime.datetime.now()
# Out:
# Target sentences loaded
# Source sentences loaded
# Sentences preprocessed
# ### Could not find a term of the sentence 'and' with index 299392 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'And:' with index 548101 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'and' with index 543751 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'and' with index 289416 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'and' with index 407945 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'and' with index 246928 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Banotti: 369' with index 279696 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Balfe: 259' with index 279698 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'UCITS' with index 15251 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Hooliganism' with index 77204 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'and' with index 181268 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Eurodac' with index 26774 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Transmissible spongiform encephalopathies' with index 185366 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Smet: 254' with index 279699 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Poos: 221' with index 279700 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Marinho: 189' with index 279701 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'and' with index 289943 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Detergents' with index 447387 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'and' with index 488087 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'o' with index 102430 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'o o' with index 102431 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'and' with index 254622 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Additionality' with index 29985 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'o' with index 102437 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'o o' with index 102438 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'and' with index 298405 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'and' with index 343208 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'and' with index 393509 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'and' with index 553766 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'IGC' with index 38059 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'MEDA' with index 79276 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Bronisław Geremek' with index 584999 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'It is no reproach to you;' with index 585513 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Eurodac' with index 89905 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'and' with index 471474 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'and' with index 552119 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'and' with index 289937 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'and' with index 571671 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'and' with index 177599 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'and' with index 243905 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'and' with index 177602 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'and' with index 383810 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'and' with index 167109 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'and' with index 325190 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'I am here;' with index 578376 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Rapporteurs:' with index 398539 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Scrapie' with index 10317 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'and' with index 546769 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Transmissible spongiform encephalopathies' with index 49362 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'and' with index 543318 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'ALTENER' with index 6617 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'and' with index 359645 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'and' with index 393821 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'and' with index 561130 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'and' with index 482283 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'and' with index 559214 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'There you have it;' with index 74229 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Comitology:' with index 21113 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'EUROJUST' with index 195068 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# Sentences embeddings extracted in en
# ### Could not find a term of the sentence 'Zum Änderungsantrag 2' with index 267264 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Arbeitsplan' with index 151553 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Entschließungsantrag zur Mittelmeerpolitik' with index 32771 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'und' with index 543751 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Betriebsräte und Entlassungen' with index 196617 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Zu Änderungsantrag
in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'DRINGLICHKEITSDEBATTE' with index 209203 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Tabakerzeugnisse' with index 128309 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Grenzarbeitnehmer' with index 140601 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'oder' with index 582970 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Luftvermutzung' with index 233794 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Haushaltsjahr 2001' with index 81222 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Akin Birdal' with index 42325 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Dringlichkeitsdebatte' with index 263520 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Zu Änderungsantrag 56:' with index 338281 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Zu Änderungsantrag 6:' with index 412009 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Tierarzneimittel' with index 185709 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Verbrauchsteuern auf Tabakwaren' with index 286069 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Arbeitsplan' with index 33142 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Unfallbedingte oder vorsätzliche Meeresverschmutzung' with index 58742 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Arbeitsplan' with index 278904 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Sportboote' with index 218493 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Einige Folgefragen:' with index 304511 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'und' with index 299392 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'DRINGLICHKEITSDEBATTE' with index 122240 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Arbeitsplan' with index 186752 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Chemikalienpolitik' with index 258433 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Zu Änderungsantrag 144:' with index 338304 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'ein niedriges Produktivitätsniveau und' with index 362882 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Zu Änderungsantrag 174:' with index 338311 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Änderungsantrag 3:' with index 104840 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'und' with index 407945 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Verhaltenskodex für Waffenausfuhren' with index 98701 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Zu den Änderungsanträgen 2 und 3:' with index 138640 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Hooliganismus im Sport' with index 77204 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'sowie' with index 298405 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Visumpflicht' with index 68006 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'MEDA' with index 79276 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'und' with index 471474 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Arbeitsplan' with index 210356 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Entlastungen' with index 177592 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Änderungsantrag 1' with index 140733 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Übernahmeangebot' with index 132542 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'sowie den' with index 177599 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'und' with index 177602 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Änderungsantrag 44:' with index 188870 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Schiffssicherheit' with index 190921 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Zum Änderungsantrag 5' with index 41422 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Arbeitsplan' with index 92625 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Arbeitsplan' with index 234962 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Ärmelkanaltunnel' with index 316882 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Altener' with index 6617 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Änderungsantrag 7:' with index 188889 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Änderungsantrag 41:' with index 313821 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Gurtanlegepflicht' with index 199136 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'DRINGLICHKEITSDEBATTE' with index 174564 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Schiffssicherheit' with index 274918 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Änderungsanträge 22 und 24' with index 15848 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Zum Änderungsantrag 4' with index 41448 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Jahreswirtschaftsbericht 1999' with index 18922 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Rentensysteme und Rentenfonds' with index 176617 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Zum Änderungsantrag 2:' with index 127470 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Ich nenne hier die Dinge beim Namen.' with index 74229 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Umweltpolitik' with index 198134 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Konfliktverhütung und Krisenmanagement' with index 171511 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Änderungsantrag 31' with index 15864 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Arbeitsplan' with index 175610 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Eurojust' with index 195068 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Zum Kompromißänderungsantrag 224' with index 41470 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Schiffbausektor' with index 166411 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Antipersonenminen' with index 108045 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Änderungsantrag 6' with index 15891 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Bürgerdialog' with index 78356 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Arbeitsplan' with index 67093 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'DRINGLICHKEITSDEBATTE' with index 137750 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Lebensmittelsicherheit' with index 2585 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Umweltaspekte im Entwicklungsprozeß' with index 21019 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Zum Kompromißänderungsantrag 227' with index 41504 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Antipersonenminen' with index 230945 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Arbeitsplan' with index 57898 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Beschluß über die Dringlichkeit' with index 60974 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Auftragsvergabe' with index 281135 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Risikokapital' with index 92730 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Haushaltsleitlinien 2001' with index 31292 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Lebensversicherungen' with index 173629 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Interoperabilität des transeuropäischen Eisenbahnsystems' with index 152129 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Belarus' with index 219714 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'und' with index 325190 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Außenbeziehungen' with index 36422 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Entlastungen 1998' with index 68166 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'DRINGLICHKEITSDEBATTE' with index 244300 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'und' with index 543318 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Verkehrsinfrastrukturgebühren' with index 146008 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'sowie über' with index 393821 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Haushaltsverfahren 2001' with index 105054 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Arbeitsplan' with index 245348 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Tierernährung' with index 96875 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Wasserbewirtschaftung' with index 173677 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Strukturmaßnahmen' with index 208493 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Kennzeichnungsprogramm für stromsparende Bürogeräte' with index 239216 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Komitologie:' with index 21113 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Terrorismusbekämpfung' with index 289412 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'und' with index 289416 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Arbeitszeitgestaltung' with index 49800 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Beschluß über die Dringlichkeit' with index 176778 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Arbeitsplan' with index 138900 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'CITES' with index 29333 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Rückübernahme von Drittstaatsangehörigen' with index 56982 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'und' with index 488087 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence '
in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# ### Could not find a term of the sentence 'Dringlichkeitsdebatte' with index 276478 in word embedding vocabulary and thus, could not calculate the respective embedding vector.
# Sentences embeddings extracted in de
# Sentences transformed
# Source words extracted
# Target words extracted
# Start preparation of feature num_words
# Start preparation of feature num_punctuation
# Start preparation of feature occ_question_mark
# Start preparation of feature occ_exclamation_mark
# Start preparation of feature translated_words
# Start preparation of feature num_noun
# Start preparation of feature num_verb
# Start preparation of feature num_adverb
# Start preparation of feature num_adjective
# Start preparation of feature num_wh
# Start preparation of feature num_pronoun

# %%
'Computation time loading the data: {}'.format(stop-start)
# Out:
# 'Computation time loading the data: 2:48:53.913675'

# %%
'Finished at: {}'.format(datetime.datetime.now())
# Out:
# 'Finished at: 2020-05-10 03:37:07.664611'

# %%
data.head()
# Out:
#                                    src_embedding_raw  \
# 0  [-0.07040999999999999, 0.094428, 0.1178755, -0...
# 1  [-0.05200671428571431, 0.016875466666666665, -...
# 2  [-0.08509222727272729, -0.03279808636363638, -...
# 3  [-0.064901, -0.08438565454545456, -0.008655272...
# 4  [-0.07612752, -0.011232175999999993, -0.131726...
#
#                                        src_embedding  \
# 0  [-0.30886147324594976, 0.34727272417056637, -0...
# 1  [-0.19811859957522948, 0.2886577921005607, -0....
# 2  [-0.19086391830712127, 0.07257094264933792, -0...
# 3  [-0.16132638013366773, 0.22534862126716065, -0...
# 4  [-0.1976057223610604, 0.15322830212421176, -0....
#
#                                        trg_embedding  src_embedding_0  \
# 0  [-0.22081, 0.49136, -0.09375700000000001, -0.6...     8.216237e-17
# 1  [-0.1368885, 0.29018044444444446, -0.152462499...     1.729702e-17
# 2  [-0.1190726470588235, 0.13479876470588237, -0....     6.189977e-18
# 3  [-0.12862244444444446, 0.33829177777777786, -0...     1.762167e-17
# 4  [-0.21589275000000002, 0.14882689999999996, -0...    -7.670992e-18
#
#    src_embedding_1  src_embedding_2  src_embedding_3  src_embedding_4  \
# 0    -1.597881e-16    -4.068444e-16    -2.221576e-16     1.419417e-16
# 1    -5.609655e-17    -2.504178e-16     3.718357e-16    -9.391699e-17
# 2     2.259084e-16    -8.365827e-17    -1.488593e-16    -2.098104e-16
# 3     2.499622e-16     2.280361e-16     1.051710e-16     1.793577e-16
# 4     3.138516e-16     3.794882e-16    -9.409649e-17    -6.323838e-17
#
#    src_embedding_5  src_embedding_6  src_embedding_7  src_embedding_8  \
# 0     1.382578e-15    -9.346560e-16     6.179779e-14         0.380773
# 1     3.438229e-16    -6.329894e-17     1.164346e-14         0.067536
# 2    -2.646360e-16     3.730104e-16    -1.278144e-14        -0.078386
# 3     8.556896e-17     2.781751e-17     5.155598e-15         0.033753
# 4    -5.398205e-16     3.610397e-16    -2.436940e-14        -0.148804
#
#    src_embedding_9  src_embedding_10  src_embedding_11  src_embedding_12  \
# 0         0.022238         -0.081529          0.177978          0.777999
# 1        -0.008211         -0.251567          0.045332          0.234309
# 2         0.046931         -0.089777          0.018667          0.023953
# 3        -0.015037          0.053433          0.009302          0.168709
# 4        -0.082058         -0.022891         -0.044068          0.132960
#
#    src_embedding_85  src_embedding_86  src_embedding_87  src_embedding_88  \
# 0          0.000285          0.215293         -0.121324          0.123603
# 1         -0.004982          0.045535         -0.073057          0.033066
# 2          0.035329         -0.008132          0.018833         -0.048326
# 3          0.047397          0.059502         -0.014057          0.047342
# 4          0.001428         -0.009432         -0.052684         -0.005994
#
#    src_embedding_89  src_embedding_90  src_embedding_91  src_embedding_92  \
# 0         -0.102669         -0.034351         -0.026683         -0.039467
# 1         -0.042433          0.008664         -0.001254         -0.030425
# 2         -0.032214         -0.004565         -0.033779         -0.003125
# 3          0.031181          0.032236         -0.088978         -0.053163
# 4         -0.023066          0.029172         -0.026279         -0.035531
#
#    src_embedding_93  src_embedding_94  src_embedding_95  src_embedding_96  \
# 0         -0.129126         -0.058726          0.022860         -0.018036
# 1          0.016041         -0.045837          0.036461          0.021647
# 2         -0.032141         -0.055390          0.061522         -0.035667
# 3         -0.139078         -0.013728         -0.036059          0.056840
# 4         -0.041335         -0.021163          0.049718         -0.003889
#
#    src_embedding_97  src_embedding_98  src_embedding_99  trg_embedding_0  \
# 0         -0.071643         -0.269825          0.167729     6.283087e-17
# 1          0.036671         -0.021020         -0.024238     3.922860e-18
# 2         -0.015903          0.012695         -0.036494     1.365972e-18
# 3          0.036510         -0.053764          0.015660     3.345531e-17
# 4         -0.001320          0.028777          0.010073     3.178316e-18
#
#    trg_embedding_1  trg_embedding_2  trg_embedding_3  trg_embedding_4  \
# 0    -4.325320e-16     1.893215e-15     7.750186e-16     2.603846e-16
# 1     1.283347e-16     9.858635e-17    -8.928210e-17     1.714749e-16
# 2     2.825495e-16     1.700858e-16     1.843649e-16     5.396275e-16
# 3    -2.779614e-16     9.109585e-16     1.287399e-16     2.093127e-16
# 4    -4.865957e-16    -3.037769e-16    -1.362381e-16     1.569077e-16
#
#    trg_embedding_5  trg_embedding_6  trg_embedding_7  trg_embedding_8  \
# 0     3.040002e-15     1.212927e-15     5.058454e-15        -0.122429
# 1    -5.214729e-16    -3.938689e-16    -5.551115e-17         0.023527
# 2     2.064335e-16    -8.232566e-16     1.575129e-15         0.032918
# 3     9.263000e-16     1.730973e-15    -5.481726e-16        -0.105644
# 4    -8.063535e-16    -4.998632e-16    -6.383782e-16         0.148418
#
#    trg_embedding_9  trg_embedding_10  trg_embedding_11  trg_embedding_12  \
# 0        -0.342500          0.247819         -0.027430         -0.276903
# 1         0.028267          0.056772         -0.053851         -0.040736
# 2        -0.058346          0.046501          0.007769          0.209435
# 3        -0.003995          0.131755          0.102162         -0.152176
# 4         0.164909         -0.002113         -0.112415          0.059951
#
#    trg_embedding_13  trg_embedding_14  trg_embedding_15  trg_embedding_16  \
# 0         -0.204869         -0.372475         -0.113888         -0.160526
# 1         -0.106361         -0.014717          0.128316         -0.080736
# 2         -0.194359         -0.034579          0.117234         -0.018287
# 3         -0.030849         -0.196869          0.004103         -0.055429
# 4         -0.095266         -0.046866         -0.103616          0.183888
#
#    trg_embedding_17  trg_embedding_18  trg_embedding_19  trg_embedding_20  \
#
#    trg_embedding_53  trg_embedding_54  trg_embedding_55  trg_embedding_56  \
# 0          0.071080          0.022857         -0.223459         -0.052880
# 1          0.036040         -0.071571         -0.068395          0.029850
# 2          0.013686         -0.087816         -0.032599         -0.032299
# 3          0.088198         -0.053933          0.045757          0.082990
# 4          0.054955         -0.002108          0.056580          0.081127
#
#    trg_embedding_57  trg_embedding_58  trg_embedding_59  trg_embedding_60  \
# 0          0.112539          0.096353          0.025088          0.004898
# 1         -0.008036         -0.020289         -0.075706          0.025590
# 2         -0.076679          0.130438          0.055599         -0.047965
# 3         -0.011211          0.024539          0.110410          0.042280
# 4         -0.056515          0.029267         -0.044216          0.050423
#
#    trg_embedding_61  trg_embedding_62  trg_embedding_63  trg_embedding_64  \
# 0          0.032984         -0.113661         -0.225884          0.080250
# 1         -0.146933         -0.028665         -0.005153          0.034729
# 2         -0.018349         -0.050674          0.026520         -0.052642
# 3         -0.027706         -0.015953          0.062864          0.086111
# 4          0.043544         -0.048566          0.038852         -0.003261
#
#    trg_embedding_65  trg_embedding_66  trg_embedding_67  trg_embedding_68  \
# 0          0.072391          0.145862          0.278828          0.418897
# 1         -0.031928         -0.055190          0.134644          0.027292
# 2          0.009372         -0.066512          0.087622         -0.057787
# 3         -0.043362         -0.012343         -0.113777          0.120633
# 4         -0.051335         -0.069594         -0.040271         -0.017178
#
#    trg_embedding_69  trg_embedding_70  trg_embedding_71  trg_embedding_72  \
# 0          0.191584          0.016594          0.130891          0.038679
# 1         -0.048504          0.070097          0.097207          0.013015
# 2         -0.063133         -0.067403         -0.083258         -0.066608
# 3          0.064127          0.014011          0.134351          0.050281
# 4         -0.004023         -0.075725          0.024376         -0.047222
#
#    trg_embedding_73  trg_embedding_74  trg_embedding_75  trg_embedding_76  \
# 0          0.393493          0.176918         -0.166214         -0.209126
# 1          0.113480         -0.012262         -0.050550         -0.105777
# 2         -0.006157          0.044323         -0.020022         -0.032505
# 3          0.042272          0.022644         -0.054087         -0.112875
# 4          0.069579         -0.047316         -0.029424          0.043335
#
#    trg_embedding_77  trg_embedding_78  trg_embedding_79  trg_embedding_80  \
# 0          0.031897         -0.054037          0.134932         -0.121252
# 1         -0.061792         -0.063891          0.046601         -0.032570
# 2          0.032031          0.067144         -0.003753         -0.018122
# 3          0.081495         -0.149082         -0.101887         -0.041972
# 4         -0.016750         -0.034937         -0.025133          0.051467
#
#    trg_embedding_81  trg_embedding_82  trg_embedding_83  trg_embedding_84  \
# 0          0.167371         -0.262027         -0.203298         -0.189379
# 1          0.114214          0.074532          0.058186         -0.006609
# 2         -0.027755          0.042878         -0.044157          0.000040
# 3         -0.026796          0.004341         -0.005357         -0.013189
# 4          0.035042         -0.028813         -0.057096          0.000905
#
#    trg_embedding_85  trg_embedding_86  trg_embedding_87  trg_embedding_88  \
# 0         -0.250738          0.074383          0.006604         -0.335618
# 1          0.015328         -0.026522          0.004086         -0.016931
# 2          0.080074         -0.035276         -0.016845          0.086911
# 3         -0.063392         -0.042630          0.010985         -0.038146
# 4         -0.007305         -0.003432         -0.019568         -0.028122
#
#    trg_embedding_89  trg_embedding_90  trg_embedding_91  trg_embedding_92  \
# 0         -0.257085          0.202514         -0.001576          0.206865
# 1         -0.073143          0.007680         -0.035858          0.036173
# 2          0.033430         -0.064555         -0.024578          0.011734
# 3          0.022334         -0.042969          0.043835          0.029418
# 4          0.028363         -0.036874          0.044034         -0.037297
#
#    trg_embedding_93  trg_embedding_94  trg_embedding_95  trg_embedding_96  \
# 0         -0.048495          0.174892          0.002026          0.278630
# 1          0.008664          0.014377          0.063636          0.018877
# 2         -0.030594          0.096240         -0.009311         -0.002433
# 3         -0.053046          0.090973         -0.049329          0.101628
# 4         -0.039525          0.016460          0.034618          0.005257
#
#    trg_embedding_97  trg_embedding_98  trg_embedding_99  \
# 0         -0.104404         -0.009556          0.058466
# 1          0.006522          0.017438         -0.006661
# 2          0.059765          0.005163         -0.004845
# 3         -0.020203          0.078046          0.026464
# 4          0.000146         -0.021366          0.012027
#
#                                         src_sentence  \
# 0                          Resumption of the session
# 1  I declare resumed the session of the European ...
# 2  Although, as you will have seen, the dreaded '...
# 3  You have requested a debate on this subject in...
# 4  In the meantime, I should like to observe a mi...
#
#                                         trg_sentence  \
# 0                 Wiederaufnahme der Sitzungsperiode
# 1  Ich erkläre die am Freitag, dem 17. Dezember u...
# 2  Wie Sie feststellen konnten, ist der gefürchte...
# 3  Im Parlament besteht der Wunsch nach einer Aus...
# 4  Heute möchte ich Sie bitten - das ist auch der...
#
#                                     src_preprocessed  \
# 0                              [resumption, session]
# 1  [declare, resumed, session, european, parliame...
# 2  [although, ,, seen, ,, dreaded, ', millennium,...
# 3  [requested, debate, subject, course, next, day...
# 4  [meantime, ,, like, observe, minute, ', silenc...
#
#                                     trg_preprocessed  \
# 0                  [wiederaufnahme, sitzungsperiode]
# 1  [erkläre, freitag, ,, 17, ., dezember, unterbr...
# 2  [feststellen, konnten, ,, gefürchtete, ", mill...
# 3  [parlament, besteht, wunsch, aussprache, verla...
# 4  [heute, möchte, bitten, -, wunsch, kolleginnen...
#
#                                            src_words  \
# 0                              [resumption, session]
# 1  [declare, resumed, session, european, parliame...
# 2  [although, seen, dreaded, millennium, bug, fai...
# 3  [requested, debate, subject, course, next, day...
# 4  [meantime, like, observe, minute, silence, num...
#
#                                            trg_words  src_num_words  \
# 0                  [wiederaufnahme, sitzungsperiode]              2
# 1  [erkläre, freitag, dezember, unterbrochene, si...             21
# 2  [feststellen, konnten, gefürchtete, millenium,...             17
# 3  [parlament, besteht, wunsch, aussprache, verla...              8
# 4  [heute, möchte, bitten, wunsch, kolleginnen, k...             18
#
#    trg_num_words  src_num_punctuation  trg_num_punctuation  \
# 0              2                    0                    0
# 1             16                    2                    5
# 2             13                    6                    6
# 3              8                    3                    1
# 4             15                    7                    6
#
#    src_occ_question_mark  trg_occ_question_mark  src_occ_exclamation_mark  \
# 0                  False                  False                     False
# 1                  False                  False                     False
# 2                  False                  False                     False
# 3                  False                  False                     False
# 4                  False                  False                     False
#
#    trg_occ_exclamation_mark  \
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
#
#                                 src_translated_words  \
# 0        [sitzungsperiode, sitzung, tagung, session]
# 1  [sitzungsperiode, sitzung, tagung, session, eu...
# 2  [zwar, obgleich, obwohl, gesehen, sah, geschei...
# 3  [beantragt, angefordert, beantragte, gewünscht...
# 4  [mögen, gefällt, wie, like, minute, nummer, an...
#
#                                 trg_translated_words  src_num_noun  \
# 0                                                 []             2
# 1  [friday, fridays, december, dec, european, goo...             6
# 2  [detect, couldn, citizens, citizen, our, ours,...             8
# 3  [parliament, parliaments, ep, consists, insist...             5
# 4  [today, wants, pleas, beg, desire, wish, colle...             9
#
#    trg_num_noun  src_num_verb  trg_num_verb  src_num_adverb  trg_num_adverb  \
# 0             2             0             0               0               0
# 1            11             6             2               1               0
# 2            11             4             2               2               0
# 3             7             1             0               0               0
# 4             9             3             1               2               1
#
#    src_num_adjective  trg_num_adjective  src_num_wh  trg_num_wh  \
# 0                  0                  0           0           0
# 1                  5                  2           0           0
# 2                  2                  2           0           0
# 3                  2                  1           0           0
# 4                  3                  3           0           0
#
#    src_num_pronoun  trg_num_pronoun
# 0                0                0
# 1                0                0
# 2                1                0
# 3                0                0
# 4                0                0

# %% [markdown]
# ## Create training set

# %%
start = datetime.datetime.now()
train_data = sens.create_train_set(n_train=500000, frac_pos=0.5)
stop = datetime.datetime.now()
# Out:
# ---- Create training set ----
# # Translation dataframe created
# # Non-translation dataframe created
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-44949853f52c> in <module>
#       1 start = datetime.datetime.now()
# ----> 2 train_data = sens.create_train_set(n_train=500000, frac_pos=0.5)
#       3 stop = datetime.datetime.now()
#
# ~/Desktop/Admin/Uni-Mannheim/02_Courses/2020_FSS/Information-Retrieval/03_Project/03_Implementation/03_Feature-Selection/ir-crosslingual/ir_crosslingual/sentences/sentences.py in create_train_set(self, n_train, frac_pos)
#     396         return self.data
#     397
# --> 398     def build_separate_prepared_features_list(self):
#     399         self.src_prepared_features = ['src_{}'.format(feature)
#     400                                       for feature in
#
# ~/Desktop/Admin/Uni-Mannheim/02_Courses/2020_FSS/Information-Retrieval/03_Project/03_Implementation/03_Feature-Selection/ir-crosslingual/ir_crosslingual/sentences/sentences.py in <listcomp>(.0)
#     396         return self.data
#     397
# --> 398     def build_separate_prepared_features_list(self):
#     399         self.src_prepared_features = ['src_{}'.format(feature)
#     400                                       for feature in
#
# KeyboardInterrupt:

# %%
'Computation time training set extraction: {}'.format(stop-start)

# %%
'Finished at: {}'.format(datetime.datetime.now())

# %% [markdown]
# ## Create test collection

# %%
start = datetime.datetime.now()
test_collection = sens.create_test_collection(n_queries=1000, n_docs=10000)
stop = datetime.datetime.now()

# %%
'Computation time test collection extraction: {}'.format(stop-start)

# %%
'Finished at: {}'.format(datetime.datetime.now())

# %% [markdown]
# ## Feature extraction

# %%
train_test, test_collection = sens.extract_features(features_dict='all', data='train_test', drop_prepared=False)

# %%
'Finished at: {}'.format(datetime.datetime.now())

# %%
train_data.head()

# %%
test_collection.head()

# %%
train_data.to_pickle(f'{paths.data_path}extracted-data/global/training_data_avg.pkl')

# %%
'Finished at: {}'.format(datetime.datetime.now())

# %%
test_collection.to_pickle(f'{paths.data_path}extracted-data/global/test_collection_avg.pkl')

# %%
'Finished at: {}'.format(datetime.datetime.now())

# %%
overall_stop = datetime.datetime.now()

# %%
'Total computation time: {}'.format(overall_stop-overall_start)

# %% [markdown]
# # ! Save idf values ! #
