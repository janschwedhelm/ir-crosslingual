# %% [markdown]
# ## Imports

# %%
import io, os, importlib, pickle
import datetime
import pandas as pd

import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
from ir_crosslingual.utils import paths
importlib.reload(paths)

from ir_crosslingual.features import text_based
importlib.reload(text_based)

from ir_crosslingual.features import vector_based
importlib.reload(vector_based)

from ir_crosslingual.embeddings import embeddings
importlib.reload(embeddings)

from ir_crosslingual.sentences import sentences
importlib.reload(sentences)
# Out:
# <module 'ir_crosslingual.sentences.sentences' from '/Users/jani/PycharmProjects/ir-crosslingual/ir_crosslingual/sentences/sentences.py'>

# %%
def time(start, stop):
    print('Computation time loading the data: {}'.format(stop-start))
    print('Finished at: {}'.format(datetime.datetime.now()))

# %% [markdown]
# ## Load word embeddings

# %%
overall_start = datetime.datetime.now()

# %%
german = embeddings.WordEmbeddings('de')
german.load_embeddings()

english = embeddings.WordEmbeddings('en')
english.load_embeddings()

# %%
W_ende, W_deen = embeddings.WordEmbeddings.learn_projection_matrix(src_lang='en', trg_lang='de')
# Out:
# ---- INFO: Learn projection matrix for en-de
# ---- INFO: Found 13700 valid translation pairs in expert dictionary.
# ---- INFO: 977 other pairs contained at least one unknown word (0 in source language, 977 in target language).
# ---- DONE: Seed dictionary extracted for the languages: en-de
# ---- INFO: Resulting subspace dimension: (13700, 300)
# ---- INFO: Resulting subspace dimension: (13700, 300)
# ---- DONE: Projection matrix from en to de
# ---- INFO: Learn projection matrix for de-en
# ---- INFO: Found 10604 valid translation pairs in expert dictionary.
# ---- INFO: 262 other pairs contained at least one unknown word (0 in source language, 262 in target language).
# ---- DONE: Seed dictionary extracted for the languages: de-en
# ---- INFO: Resulting subspace dimension: (10604, 300)
# ---- INFO: Resulting subspace dimension: (10604, 300)
# ---- DONE: Projection matrix from de to en

# %% [markdown]
# ## Load sentence embeddings

# %%
start = datetime.datetime.now()
sens = sentences.Sentences(src_words=english, trg_words=german)
prepared_features = list(text_based.PREPARED_FEATURES.keys())
data = sens.load_data(single_source=False, n_max=600000, features=prepared_features, agg_method='average')
stop = datetime.datetime.now()
# Out:
# ---- DONE: Target sentences loaded
# ---- DONE: Source sentences loaded
# ---- DONE: Sentences preprocessed
# ---- ERROR: Sentence embedding failed in en on ID 299392: and
# ---- ERROR: Sentence embedding failed in en on ID 548101: And:
# ---- ERROR: Sentence embedding failed in en on ID 543751: and
# ---- ERROR: Sentence embedding failed in en on ID 289416: and
# ---- ERROR: Sentence embedding failed in en on ID 407945: and
# ---- ERROR: Sentence embedding failed in en on ID 246928: and
# ---- ERROR: Sentence embedding failed in en on ID 279696: Banotti: 369
# ---- ERROR: Sentence embedding failed in en on ID 279698: Balfe: 259
# ---- ERROR: Sentence embedding failed in en on ID 15251: UCITS
# ---- ERROR: Sentence embedding failed in en on ID 77204: Hooliganism
# ---- ERROR: Sentence embedding failed in en on ID 181268: and
# ---- ERROR: Sentence embedding failed in en on ID 26774: Eurodac
# ---- ERROR: Sentence embedding failed in en on ID 185366: Transmissible spongiform encephalopathies
# ---- ERROR: Sentence embedding failed in en on ID 279699: Smet: 254
# ---- ERROR: Sentence embedding failed in en on ID 279700: Poos: 221
# ---- ERROR: Sentence embedding failed in en on ID 279701: Marinho: 189
# ---- ERROR: Sentence embedding failed in en on ID 289943: and
# ---- ERROR: Sentence embedding failed in en on ID 447387: Detergents
# ---- ERROR: Sentence embedding failed in en on ID 488087: and
# ---- ERROR: Sentence embedding failed in en on ID 102430: o
# ---- ERROR: Sentence embedding failed in en on ID 102431: o o
# ---- ERROR: Sentence embedding failed in en on ID 254622: and
# ---- ERROR: Sentence embedding failed in en on ID 29985: Additionality
# ---- ERROR: Sentence embedding failed in en on ID 102437: o
# ---- ERROR: Sentence embedding failed in en on ID 102438: o o
# ---- ERROR: Sentence embedding failed in en on ID 298405: and
# ---- ERROR: Sentence embedding failed in en on ID 343208: and
# ---- ERROR: Sentence embedding failed in en on ID 393509: and
# ---- ERROR: Sentence embedding failed in en on ID 553766: and
# ---- ERROR: Sentence embedding failed in en on ID 38059: IGC
# ---- ERROR: Sentence embedding failed in en on ID 79276: MEDA
# ---- ERROR: Sentence embedding failed in en on ID 584999: Bronisław Geremek
# ---- ERROR: Sentence embedding failed in en on ID 585513: It is no reproach to you;
# ---- ERROR: Sentence embedding failed in en on ID 89905: Eurodac
# ---- ERROR: Sentence embedding failed in en on ID 471474: and
# ---- ERROR: Sentence embedding failed in en on ID 552119: and
# ---- ERROR: Sentence embedding failed in en on ID 289937: and
# ---- ERROR: Sentence embedding failed in en on ID 571671: and
# ---- ERROR: Sentence embedding failed in en on ID 177599: and
# ---- ERROR: Sentence embedding failed in en on ID 243905: and
# ---- ERROR: Sentence embedding failed in en on ID 177602: and
# ---- ERROR: Sentence embedding failed in en on ID 383810: and
# ---- ERROR: Sentence embedding failed in en on ID 167109: and
# ---- ERROR: Sentence embedding failed in en on ID 325190: and
# ---- ERROR: Sentence embedding failed in en on ID 578376: I am here;
# ---- ERROR: Sentence embedding failed in en on ID 398539: Rapporteurs:
# ---- ERROR: Sentence embedding failed in en on ID 10317: Scrapie
# ---- ERROR: Sentence embedding failed in en on ID 546769: and
# ---- ERROR: Sentence embedding failed in en on ID 49362: Transmissible spongiform encephalopathies
# ---- ERROR: Sentence embedding failed in en on ID 543318: and
# ---- ERROR: Sentence embedding failed in en on ID 6617: ALTENER
# ---- ERROR: Sentence embedding failed in en on ID 359645: and
# ---- ERROR: Sentence embedding failed in en on ID 393821: and
# ---- ERROR: Sentence embedding failed in en on ID 561130: and
# ---- ERROR: Sentence embedding failed in en on ID 482283: and
# ---- ERROR: Sentence embedding failed in en on ID 559214: and
# ---- ERROR: Sentence embedding failed in en on ID 74229: There you have it;
# ---- ERROR: Sentence embedding failed in en on ID 21113: Comitology:
# ---- ERROR: Sentence embedding failed in en on ID 195068: EUROJUST
# ---- INFO: Sentences embeddings extracted in en
# ---- ERROR: Sentence embedding failed in de on ID 267264: Zum Änderungsantrag 2
# ---- ERROR: Sentence embedding failed in de on ID 151553: Arbeitsplan
# ---- ERROR: Sentence embedding failed in de on ID
# ---- ERROR: Sentence embedding failed in de on ID 76770: Dringlichkeitsdebatte
# ---- ERROR: Sentence embedding failed in de on ID 482280: Kohäsionspolitik
# ---- ERROR: Sentence embedding failed in de on ID 561130: und
# ---- ERROR: Sentence embedding failed in de on ID 482283: und
# ---- ERROR: Sentence embedding failed in de on ID 93172: Seehäfen und Binnenhäfen
# ---- ERROR: Sentence embedding failed in de on ID 219127: Dringlichkeitsdebatte
# ---- ERROR: Sentence embedding failed in de on ID 110584: Umwelthormone
# ---- ERROR: Sentence embedding failed in de on ID 28665: Westsahara
# ---- ERROR: Sentence embedding failed in de on ID 27643: Informationsgesellschaft
# ---- ERROR: Sentence embedding failed in de on ID 276478: Dringlichkeitsdebatte
# ---- INFO: Sentences embeddings extracted in de
# ---- DONE: Sentences transformed
# ---- INFO: Embedding space of source language transformed according to projection matrix
# ---- DONE: Source words extracted
# ---- DONE: Target words extracted
# ---- INFO: Start preparation of text-based feature translated_words
# ---- INFO: Start preparation of text-based feature num_words
# ---- INFO: Start preparation of text-based feature num_punctuation
# ---- INFO: Start preparation of text-based feature occ_question_mark
# ---- INFO: Start preparation of text-based feature occ_exclamation_mark
# ---- DONE: All features prepared
# ---- DONE: Dropped duplicates and created full dataset
# ---- INFO: Length of dataset after preprocessing and duplicate handling: 589164

# %%
len(data)
# Out:
# 589164

# %%
time(start, stop)
# Out:
# Computation time loading the data: 0:09:10.688021
# Finished at: 2020-05-12 22:12:17.003642

# %%
data.head()
# Out:
#                                        src_embedding  \
# 0  [-0.07040999999999999, 0.094428, 0.1178755, -0...
# 1  [-0.05200671428571431, 0.016875466666666665, -...
# 2  [-0.08509222727272729, -0.03279808636363638, -...
# 3  [-0.064901, -0.08438565454545456, -0.008655272...
# 4  [-0.07612752, -0.011232175999999993, -0.131726...
#
#                                src_embedding_aligned  \
# 0  [-0.3088614732459478, 0.3472727241705731, -0.2...
# 1  [-0.19811859957522993, 0.2886577921005622, -0....
# 2  [-0.19086391830712227, 0.07257094264933953, -0...
# 3  [-0.1613263801336713, 0.22534862126715746, -0....
# 4  [-0.19760572236106183, 0.15322830212421143, -0...
#
#                                        trg_embedding  \
# 0  [-0.22081, 0.49136, -0.09375700000000001, -0.6...
# 1  [-0.1368885, 0.29018044444444446, -0.152462499...
# 2  [-0.1190726470588235, 0.13479876470588237, -0....
# 3  [-0.12862244444444446, 0.33829177777777786, -0...
# 4  [-0.21589275000000002, 0.14882689999999996, -0...
#
#                                         src_sentence  \
# 0                          Resumption of the session
# 1  I declare resumed the session of the European ...
# 2  Although, as you will have seen, the dreaded '...
# 3  You have requested a debate on this subject in...
# 4  In the meantime, I should like to observe a mi...
#
#                                         trg_sentence  \
# 0                 Wiederaufnahme der Sitzungsperiode
# 1  Ich erkläre die am Freitag, dem 17. Dezember u...
# 2  Wie Sie feststellen konnten, ist der gefürchte...
# 3  Im Parlament besteht der Wunsch nach einer Aus...
# 4  Heute möchte ich Sie bitten - das ist auch der...
#
#                                     src_preprocessed  \
# 0                              [resumption, session]
# 1  [declare, resumed, session, european, parliame...
# 2  [although, ,, seen, ,, dreaded, ', millennium,...
# 3  [requested, debate, subject, course, next, day...
# 4  [meantime, ,, like, observe, minute, ', silenc...
#
#                                     trg_preprocessed  \
# 0                  [wiederaufnahme, sitzungsperiode]
# 1  [erkläre, freitag, ,, 17, ., dezember, unterbr...
# 2  [feststellen, konnten, ,, gefürchtete, ", mill...
# 3  [parlament, besteht, wunsch, aussprache, verla...
# 4  [heute, möchte, bitten, -, wunsch, kolleginnen...
#
#                                            src_words  \
# 0                              [resumption, session]
# 1  [declare, resumed, session, european, parliame...
# 2  [although, seen, dreaded, millennium, bug, fai...
# 3  [requested, debate, subject, course, next, day...
# 4  [meantime, like, observe, minute, silence, num...
#
#                                            trg_words  \
# 0                  [wiederaufnahme, sitzungsperiode]
# 1  [erkläre, freitag, dezember, unterbrochene, si...
# 2  [feststellen, konnten, gefürchtete, millenium,...
# 3  [parlament, besteht, wunsch, aussprache, verla...
# 4  [heute, möchte, bitten, wunsch, kolleginnen, k...
#
#                                 src_translated_words  \
# 0        [sitzungsperiode, sitzung, tagung, session]
# 1  [sitzungsperiode, sitzung, tagung, session, eu...
# 2  [zwar, obgleich, obwohl, gesehen, sah, geschei...
# 3  [beantragt, angefordert, beantragte, gewünscht...
# 4  [mögen, gefällt, wie, like, minute, nummer, an...
#
#                                 trg_translated_words  src_num_words  \
# 0                                                 []              2
# 1  [friday, fridays, december, dec, european, goo...             21
# 2  [detect, couldn, citizens, citizen, our, ours,...             17
# 3  [parliament, parliaments, ep, consists, insist...              8
# 4  [today, wants, pleas, beg, desire, wish, colle...             18
#
#    trg_num_words  src_num_punctuation  trg_num_punctuation  \
# 0              2                    0                    0
# 1             16                    2                    5
# 2             13                    6                    6
# 3              8                    3                    1
# 4             15                    7                    6
#
#    src_occ_question_mark  trg_occ_question_mark  src_occ_exclamation_mark  \
# 0                  False                  False                     False
# 1                  False                  False                     False
# 2                  False                  False                     False
# 3                  False                  False                     False
# 4                  False                  False                     False
#
#    trg_occ_exclamation_mark
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False

# %% [markdown]
# ## Create training set

# %%
start = datetime.datetime.now()
train_data = sens.create_train_set(n_train=500000, frac_pos=0.5)
stop = datetime.datetime.now()
# Out:
# ---- INFO: Translation dataframe created
# ---- INFO: Non-translation dataframe created
# ---- INFO: Determined and shuffled non-translation indices
# ---- INFO: Feature column trg_sentence appended
# ---- INFO: Feature column trg_preprocessed appended
# ---- INFO: Feature column trg_embedding appended
# ---- INFO: Feature column trg_words appended
# ---- INFO: Feature column trg_translated_words appended
# ---- INFO: Feature column trg_num_words appended
# ---- INFO: Feature column trg_num_punctuation appended
# ---- INFO: Feature column trg_occ_question_mark appended
# ---- INFO: Feature column trg_occ_exclamation_mark appended
# ---- INFO: All features appended
# ---- INFO: Added non-translation indicator
# ---- DONE: Training dataset created

# %%
time(start, stop)
# Out:
# Computation time loading the data: 0:00:04.477559
# Finished at: 2020-05-12 22:12:21.589882

# %% [markdown]
# ## Create test collection

# %%
start = datetime.datetime.now()
test_collection = sens.create_test_collection(n_queries=1000, n_docs=10000)
stop = datetime.datetime.now()
# Out:
# ---- INFO: Preliminary queries dataframe created
# ---- INFO: Preliminary documentes dataframe created
# ---- INFO: Merged queries and documents dataframe
# ---- INFO: Merged with test dataframe
# ---- INFO: Added translation indicator
# ---- DONE: Test collection created

# %%
time(start, stop)
# Out:
# Computation time loading the data: 0:01:04.869158
# Finished at: 2020-05-12 22:13:26.498023

# %% [markdown]
# ## Feature extraction

# %%
features_dict = {'text_based': list(text_based.FEATURES.keys()), 
                 'vector_based': list(vector_based.FEATURES.keys())}

# %%
start = datetime.datetime.now()
train_test, test_collection = sens.extract_features(features_dict=features_dict, data='train_test', drop_prepared=False)
stop = datetime.datetime.now()
# Out:
# ---- INFO: No vector elements as features specified
# ---- INFO: Started extraction of text-based feature norm_diff_translated_words
# ---- INFO: Started extraction of text-based feature abs_diff_num_words
# ---- INFO: Started extraction of text-based feature abs_diff_num_punctuation
# ---- INFO: Started extraction of text-based feature abs_diff_occ_question_mark
# ---- INFO: Started extraction of text-based feature abs_diff_occ_exclamation_mark
# ---- INFO: Started extraction of text-based feature rel_diff_num_words
# ---- INFO: Started extraction of text-based feature rel_diff_num_punctuation
# ---- INFO: Started extraction of text-based feature norm_diff_num_words
# ---- INFO: Started extraction of text-based feature norm_diff_num_punctuation
# ---- INFO: Started extraction of vector-based feature euclidean_distance
# ---- INFO: Started extraction of vector-based feature cosine_similarity
# ---- DONE: All given features extracted on train dataset
# -----------------------
# ---- INFO: Started extraction of text-based feature norm_diff_translated_words
# ---- INFO: Started extraction of text-based feature abs_diff_num_words
# ---- INFO: Started extraction of text-based feature abs_diff_num_punctuation
# ---- INFO: Started extraction of text-based feature abs_diff_occ_question_mark
# ---- INFO: Started extraction of text-based feature abs_diff_occ_exclamation_mark
# ---- INFO: Started extraction of text-based feature rel_diff_num_words
# ---- INFO: Started extraction of text-based feature rel_diff_num_punctuation
# ---- INFO: Started extraction of text-based feature norm_diff_num_words
# ---- INFO: Started extraction of text-based feature norm_diff_num_punctuation
# ---- INFO: Started extraction of vector-based feature euclidean_distance
# ---- INFO: Started extraction of vector-based feature cosine_similarity
# ---- DONE: All given features extracted on test collection

# %%
time(start, stop)
# Out:
# Computation time loading the data: 2:51:42.662933
# Finished at: 2020-05-13 01:05:09.303508

# %% [markdown]
# ## View data

# %%
train_data.head()
# Out:
#                                        src_embedding  \
# 0  [-0.07040999999999999, 0.094428, 0.1178755, -0...
# 1  [-0.05200671428571431, 0.016875466666666665, -...
# 2  [-0.08509222727272729, -0.03279808636363638, -...
# 3  [-0.064901, -0.08438565454545456, -0.008655272...
# 4  [-0.07612752, -0.011232175999999993, -0.131726...
#
#                                src_embedding_aligned  \
# 0  [-0.3088614732459478, 0.3472727241705731, -0.2...
# 1  [-0.19811859957522993, 0.2886577921005622, -0....
# 2  [-0.19086391830712227, 0.07257094264933953, -0...
# 3  [-0.1613263801336713, 0.22534862126715746, -0....
# 4  [-0.19760572236106183, 0.15322830212421143, -0...
#
#                                        trg_embedding  \
# 0  [-0.22081, 0.49136, -0.09375700000000001, -0.6...
# 1  [-0.1368885, 0.29018044444444446, -0.152462499...
# 2  [-0.1190726470588235, 0.13479876470588237, -0....
# 3  [-0.12862244444444446, 0.33829177777777786, -0...
# 4  [-0.21589275000000002, 0.14882689999999996, -0...
#
#                                         src_sentence  \
# 0                          Resumption of the session
# 1  I declare resumed the session of the European ...
# 2  Although, as you will have seen, the dreaded '...
# 3  You have requested a debate on this subject in...
# 4  In the meantime, I should like to observe a mi...
#
#                                         trg_sentence  \
# 0                 Wiederaufnahme der Sitzungsperiode
# 1  Ich erkläre die am Freitag, dem 17. Dezember u...
# 2  Wie Sie feststellen konnten, ist der gefürchte...
# 3  Im Parlament besteht der Wunsch nach einer Aus...
# 4  Heute möchte ich Sie bitten - das ist auch der...
#
#                                     src_preprocessed  \
# 0                              [resumption, session]
# 1  [declare, resumed, session, european, parliame...
# 2  [although, ,, seen, ,, dreaded, ', millennium,...
# 3  [requested, debate, subject, course, next, day...
# 4  [meantime, ,, like, observe, minute, ', silenc...
#
#                                     trg_preprocessed  \
# 0                  [wiederaufnahme, sitzungsperiode]
# 1  [erkläre, freitag, ,, 17, ., dezember, unterbr...
# 2  [feststellen, konnten, ,, gefürchtete, ", mill...
# 3  [parlament, besteht, wunsch, aussprache, verla...
# 4  [heute, möchte, bitten, -, wunsch, kolleginnen...
#
#                                            src_words  \
# 0                              [resumption, session]
# 1  [declare, resumed, session, european, parliame...
# 2  [although, seen, dreaded, millennium, bug, fai...
# 3  [requested, debate, subject, course, next, day...
# 4  [meantime, like, observe, minute, silence, num...
#
#                                            trg_words  \
# 0                  [wiederaufnahme, sitzungsperiode]
# 1  [erkläre, freitag, dezember, unterbrochene, si...
# 2  [feststellen, konnten, gefürchtete, millenium,...
# 3  [parlament, besteht, wunsch, aussprache, verla...
# 4  [heute, möchte, bitten, wunsch, kolleginnen, k...
#
#                                 src_translated_words  \
# 0        [sitzungsperiode, sitzung, tagung, session]
# 1  [sitzungsperiode, sitzung, tagung, session, eu...
# 2  [zwar, obgleich, obwohl, gesehen, sah, geschei...
# 3  [beantragt, angefordert, beantragte, gewünscht...
# 4  [mögen, gefällt, wie, like, minute, nummer, an...
#
#                                 trg_translated_words  src_num_words  \
# 0                                                 []              2
# 1  [friday, fridays, december, dec, european, goo...             21
# 2  [detect, couldn, citizens, citizen, our, ours,...             17
# 3  [parliament, parliaments, ep, consists, insist...              8
# 4  [today, wants, pleas, beg, desire, wish, colle...             18
#
#    trg_num_words  src_num_punctuation  trg_num_punctuation  \
# 0              2                    0                    0
# 1             16                    2                    5
# 2             13                    6                    6
# 3              8                    3                    1
# 4             15                    7                    6
#
#    src_occ_question_mark  trg_occ_question_mark  src_occ_exclamation_mark  \
# 0                  False                  False                     False
# 1                  False                  False                     False
# 2                  False                  False                     False
# 3                  False                  False                     False
# 4                  False                  False                     False
#
#    trg_occ_exclamation_mark  translation  norm_diff_translated_words  \
# 0                     False            1                    0.250000
# 1                     False            1                    0.305263
# 2                     False            1                    0.000000
# 3                     False            1                    0.375000
# 4                     False            1                    0.338889
#
#    abs_diff_num_words  abs_diff_num_punctuation  abs_diff_occ_question_mark  \
# 0                   0                         0                           1
# 1                   5                         3                           1
# 2                   4                         0                           1
# 3                   0                         2                           1
# 4                   3                         1                           1
#
#    abs_diff_occ_exclamation_mark  rel_diff_num_words  \
# 0                              1                   0
# 1                              1                   5
# 2                              1                   4
# 3                              1                   0
# 4                              1                   3
#
#    rel_diff_num_punctuation  norm_diff_num_words  norm_diff_num_punctuation  \
# 0                         0             0.000000                   0.000000
# 1                        -3             0.277778                  -1.000000
# 2                         0             0.266667                   0.000000
# 3                         2             0.000000                   1.000000
# 4                         1             0.187500                   0.166667
#
#    euclidean_distance  cosine_similarity
# 0            2.806763           0.699530
# 1            0.989671           0.875350
# 2            1.046691           0.842287
# 3            1.517368           0.749109
# 4            0.871747           0.887995

# %%
test_collection.head()
# Out:
#                                         src_sentence  \
# 0  I would also like to comment on the budget for...
# 1  I would also like to comment on the budget for...
# 2  I would also like to comment on the budget for...
# 3  I would also like to comment on the budget for...
# 4  I would also like to comment on the budget for...
#
#                                    src_preprocessed  \
# 0  [would, also, like, comment, budget, culture, .]
# 1  [would, also, like, comment, budget, culture, .]
# 2  [would, also, like, comment, budget, culture, .]
# 3  [would, also, like, comment, budget, culture, .]
# 4  [would, also, like, comment, budget, culture, .]
#
#                                        src_embedding  \
# 0  [-0.13882914285714285, -0.017381557142857138, ...
# 1  [-0.13882914285714285, -0.017381557142857138, ...
# 2  [-0.13882914285714285, -0.017381557142857138, ...
# 3  [-0.13882914285714285, -0.017381557142857138, ...
# 4  [-0.13882914285714285, -0.017381557142857138, ...
#
#                                src_embedding_aligned  \
# 0  [-0.05674507137870465, 0.04452169555670625, -0...
# 1  [-0.05674507137870465, 0.04452169555670625, -0...
# 2  [-0.05674507137870465, 0.04452169555670625, -0...
# 3  [-0.05674507137870465, 0.04452169555670625, -0...
# 4  [-0.05674507137870465, 0.04452169555670625, -0...
#
#                                        src_words  \
# 0  [would, also, like, comment, budget, culture]
# 1  [would, also, like, comment, budget, culture]
# 2  [would, also, like, comment, budget, culture]
# 3  [would, also, like, comment, budget, culture]
# 4  [would, also, like, comment, budget, culture]
#
#                                 src_translated_words  src_num_words  \
# 0  [würden, wäre, hätte, würde, gäbe, ausserdem, ...              6
# 1  [würden, wäre, hätte, würde, gäbe, ausserdem, ...              6
# 2  [würden, wäre, hätte, würde, gäbe, ausserdem, ...              6
# 3  [würden, wäre, hätte, würde, gäbe, ausserdem, ...              6
# 4  [würden, wäre, hätte, würde, gäbe, ausserdem, ...              6
#
#    src_num_punctuation  src_occ_question_mark  src_occ_exclamation_mark  \
# 0                    1                  False                     False
# 1                    1                  False                     False
# 2                    1                  False                     False
# 3                    1                  False                     False
# 4                    1                  False                     False
#
#                                         trg_sentence  \
# 0                     Eine Bemerkung zum Kulturetat.
# 1  Ich bin nun seit ganz kurzer Zeit zweite stell...
# 2  Genau so ist es mit unseren Möglichkeiten, den...
# 3  Wenn wir denn wirklich mit der Lissabon-Strate...
# 4  Denn in Jugend und Intelligenz zu investieren,...
#
#                                     trg_preprocessed  \
# 0                         [bemerkung, kulturetat, .]
# 1  [seit, ganz, kurzer, zeit, zweite, stellvertre...
# 2  [genau, möglichkeiten, ,, klassischen, teil, a...
# 3  [wirklich, lissabon, -, strategie, ,, nämlich,...
# 4  [jugend, intelligenz, investieren, ,, wirklich...
#
#                                        trg_embedding  \
# 0  [-0.031845, 0.229315, 0.021962000000000002, -0...
# 1  [-0.1876736827586207, 0.10062845862068968, -0....
# 2  [-0.07780442857142857, 0.045667428571428574, -...
# 3  [-0.1879221111111111, 0.030884555555555557, -0...
# 4  [-0.15326981818181815, 0.07748509090909092, -0...
#
#                                            trg_words  \
# 0                            [bemerkung, kulturetat]
# 1  [seit, ganz, kurzer, zeit, zweite, stellvertre...
# 2  [genau, möglichkeiten, klassischen, teil, agra...
# 3  [wirklich, lissabon, strategie, nämlich, ökono...
# 4  [jugend, intelligenz, investieren, wirklichen,...
#
#                                 trg_translated_words  trg_num_words  \
# 0                                                 []              2
# 1  [since, ganz, quite, short, brief, zeit, perio...             24
# 2  [precisely, exact, exactly, possibilities, opt...              7
# 3  [truly, really, lisboa, lisbon, namely, rebuil...             13
# 4  [youth, teens, teenager, young, adolescence, m...              9
#
#    trg_num_punctuation  trg_occ_question_mark  trg_occ_exclamation_mark  \
# 0                    1                  False                     False
# 1                    9                  False                     False
# 2                    2                  False                     False
# 3                    6                  False                     False
# 4                    3                  False                     False
#
#    translation  norm_diff_translated_words  abs_diff_num_words  \
# 0            1                    0.250000                   4
# 1            0                    0.107143                  18
# 2            0                    0.000000                   1
# 3            0                    0.000000                   7
# 4            0                    0.000000                   3
#
#    abs_diff_num_punctuation  abs_diff_occ_question_mark  \
# 0                         0                           1
# 1                         8                           1
# 2                         1                           1
# 3                         5                           1
# 4                         2                           1
#
#    abs_diff_occ_exclamation_mark  rel_diff_num_words  \
# 0                              1                   4
# 1                              1                 -18
# 2                              1                  -1
# 3                              1                  -7
# 4                              1                  -3
#
#    rel_diff_num_punctuation  norm_diff_num_words  norm_diff_num_punctuation  \
# 0                         0             1.000000                   0.000000
# 1                        -8            -1.200000                  -1.600000
# 2                        -1            -0.166667                  -1.000000
# 3                        -5            -0.777778                  -1.666667
# 4                        -2            -0.428571                  -1.000000
#
#    euclidean_distance  cosine_similarity
# 0            1.883290           0.634981
# 1            1.194338           0.796495
# 2            1.461955           0.697996
# 3            1.394792           0.729719
# 4            1.389512           0.733129

# %% [markdown]
# ## Save data

# %%
path = f'{paths.data_path}extracted_data/global'
if not os.path.exists(path):
    os.makedirs(path)

# %%
train_data.to_pickle(f'{path}/training_data_tfidf.pkl')
'Finished at: {}'.format(datetime.datetime.now())

# %%
test_collection.to_pickle(f'{path}/test_collection_tfidf.pkl')
'Finished at: {}'.format(datetime.datetime.now())

# %%
overall_stop = datetime.datetime.now()
'Total computation time: {}'.format(overall_stop-overall_start)

# %% [markdown]
# ## For tfidf only: Save idf values

# %%
idf_en = {k: sens.vectorizer['en'].idf_[v] for k,v in sens.vectorizer['en'].vocabulary_.items()}

# %%
idf_de = {k: sens.vectorizer['de'].idf_[v] for k,v in sens.vectorizer['de'].vocabulary_.items()}

# %%
with open(f'{path}/idf_english.json', 'wb') as fp:
    pickle.dump(idf_en, fp, protocol=pickle.HIGHEST_PROTOCOL)
'Finished at: {}'.format(datetime.datetime.now())

# %%
with open(f'{path}/idf_german.json', 'wb') as fp:
    pickle.dump(idf_de, fp, protocol=pickle.HIGHEST_PROTOCOL)
'Finished at: {}'.format(datetime.datetime.now())
